# %%
from yahooquery import Screener

s = Screener()
data = s.get_screeners('all_cryptocurrencies_us')
# Access the 'symbol' field from the data object
symbols = [item['symbol'] for item in data['all_cryptocurrencies_us']['quotes']]

# Print the symbols
for symbol in symbols:
    print(symbol)
# Out:
# BTC-USD
# ETH-USD
# USDT-USD
# BNB-USD
# USDC-USD
# XRP-USD
# ADA-USD
# STETH-USD
# DOGE-USD
# MATIC-USD
# WTRX-USD
# SOL-USD
# TRX-USD
# LTC-USD
# DOT-USD
# BUSD-USD
# SHIB-USD
# AVAX-USD
# DAI-USD
# HEX-USD
# WBTC-USD
# LINK-USD
# LEO-USD
# ATOM-USD
# UNI7083-USD

# %%
data['all_cryptocurrencies_us']['quotes']
# Out:
# [{'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'CRYPTOCURRENCY',
#   'typeDisp': 'Cryptocurrency',
#   'quoteSourceName': 'CoinMarketCap',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'fiftyDayAverage': 28404.455,
#   'fiftyDayAverageChange': -1603.8945,
#   'fiftyDayAverageChangePercent': -0.0564663,
#   'twoHundredDayAverage': 22560.615,
#   'twoHundredDayAverageChange': 4239.9453,
#   'twoHundredDayAverageChangePercent': 0.18793571,
#   'marketCap': 519406419968,
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'UTC',
#   'exchangeTimezoneShortName': 'UTC',
#   'regularMarketChangePercent': -0.37086627,
#   'currency': 'USD',
#   'fiftyTwoWeekLowChange': 11201.514,
#   'fiftyTwoWeekLowChangePercent': 0.71808964,
#   'fiftyTwoWeekRange': '15599.047 - 32249.863',
#   'fiftyTwoWeekHighChange': -5449.3027,
#   'fiftyTwoWeekHighChangePercent': -0.16897134,
#   'marketState': 'REGULAR',
#   'priceHint': 2,
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

df = yf.download('BTC-USD', start='2022-10-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
